# %% [markdown]
# <a href="https://colab.research.google.com/github/singhadarsh9191/Telecom-Churn-Analysis/blob/main/Telecom_Churn_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the libraries
import pandas as pd
import numpy as np

# %%
# load the dataset
df=pd.read_csv('/content/Telecom Churn.csv')

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
# change the data type
df['Account length']=df['Account length'].astype('object')

# %%
df['Account length']=df['Account length'].astype('int')

# %%
# find the null values in the dataset
df.isnull().sum()
# there is no null value present in the dataset
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# description
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# find the name of all the columns
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#shape
df.shape
# Out:
# (3333, 20)

# %%
# count the total number of state
df['State'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
#Total unique state
df['State'].nunique()
# Out:
# 51

# %%
# Min and maximum lenght of the account
df['Account length'].min()
# Out:
# 1

# %%
df['Account length'].unique()
# Out:
# array([128, 107, 137,  84,  75, 118, 121, 147, 117, 141,  65,  74, 168,
#         95,  62, 161,  85,  93,  76,  73,  77, 130, 111, 132, 174,  57,
#         54,  20,  49, 142, 172,  12,  72,  36,  78, 136, 149,  98, 135,
#         34, 160,  64,  59, 119,  97,  52,  60,  10,  96,  87,  81,  68,
#        125, 116,  38,  40,  43, 113, 126, 150, 138, 162,  90,  50,  82,
#        144,  46,  70,  55, 106,  94, 155,  80, 104,  99, 120, 108, 122,
#        157, 103,  63, 112,  41, 193,  61,  92, 131, 163,  91, 127, 110,
#        140,  83, 145,  56, 151, 139,   6, 115, 146, 185, 148,  32,  25,
#        179,  67,  19, 170, 164,  51, 208,  53, 105,  66,  86,  35,  88,
#        123,  45, 100, 215,  22,  33, 114,  24, 101, 143,  48,  71, 167,
#         89, 199, 166, 158, 196, 209,  16,  39, 173, 129,  44,  79,  31,
#        124,  37, 159, 194, 154,  21, 133, 224,  58,  11, 109, 102, 165,
#         18,  30, 176,  47, 190, 152,  26,  69, 186, 171,  28, 153, 169,
# ...

# %%
df['Account length'].max()
# Out:
# 243

# %%
df['Account length'].mean()
# Out:
# 101.06480648064806

# %%
df.head(3)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# make a column of of total spend min and amount
df['total_time_spend']=df['Total day minutes']+df['Total eve minutes']+df['Total night minutes']+df['Total intl minutes']

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
df['total_charge']=df['Total day charge']+df['Total eve charge']+df['Total night charge']+df['Total intl charge']

# %%
df['total_charge'].max()
# Out:
# 96.15

# %%
df['total_charge'].min()
# Out:
# 22.93

# %%
# importing the required library

import seaborn as sns
import matplotlib.pyplot as plt

# read a tips.csv file from seaborn library


# count plot on single categorical variable
sns.countplot(x ='Churn', data = df)

# Show the plot
plt.show()

# %%
df['Churn']=='False'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
df['Churn']=='True'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
false=0
true=0
for i in df['Churn']:
  if i==0:
    false=false+1
  else:
    true=true+1
print(false)
print(true)
# Out:
# 2850
# 483

# %%
df.Churn.value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['Chrun']= label_encoder.fit_transform(df['Churn'])

df['Churn'].unique()
# Out:
# array([False,  True])

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night calls  \
# 0             45.07              197.4  ...                 91
# ...

# %%
#group by
df1=df.groupby('State')['Churn'].count()

# %%
# total customer in each state
df1
# Out:
# State
# AK     52
# AL     80
# AR     55
# AZ     64
# CA     34
# CO     66
# CT     74
# DC     54
# DE     61
# FL     63
# GA     54
# HI     53
# IA     44
# ID     73
# IL     58
# IN     71
# KS     70
# KY     59
# LA     51
# MA     65
# MD     70
# ME     62
# MI     73
# MN     84
# MO     63
# MS     65
# MT     68
# NC     68
# ND     62
# NE     61
# NH     56
# NJ     68
# NM     62
# NV     66
# NY     83
# OH     78
# OK     61
# OR     78
# PA     45
# RI     65
# SC     60
# SD     60
# TN     53
# TX     72
# UT     72
# VA     77
# VT     73
# WA     66
# WI     78
# WV    106
# WY     77
# Name: Churn, dtype: int64

# %%
#Total non churn customer
df.query("Churn == 0").groupby(["State"])["Churn"].count().reset_index()
# Out:
#    State  Churn
# 0     AK     49
# 1     AL     72
# 2     AR     44
# 3     AZ     60
# 4     CA     25
# 5     CO     57
# 6     CT     62
# 7     DC     49
# 8     DE     52
# 9     FL     55
# 10    GA     46
# 11    HI     50
# 12    IA     41
# 13    ID     64
# 14    IL     53
# 15    IN     62
# 16    KS     57
# 17    KY     51
# 18    LA     47
# 19    MA     54
# 20    MD     53
# 21    ME     49
# 22    MI     57
# 23    MN     69
# 24    MO     56
# 25    MS     51
# 26    MT     54
# 27    NC     57
# 28    ND     56
# 29    NE     56
# 30    NH     47
# 31    NJ     50
# 32    NM     56
# 33    NV     52
# 34    NY     68
# 35    OH     68
# 36    OK     52
# 37    OR     67
# 38    PA     37
# 39    RI     59
# 40    SC     46
# 41    SD     52
# 42    TN     48
# 43    TX     54
# 44    UT     62
# 45    VA     72
# 46    VT     65
# 47    WA     52
# 48    WI     71
# 49    WV     96
# 50    WY     68

# %%
df.query("Churn == 1").groupby(["State"])["Churn"].count().reset_index()
# Out:
#    State  Churn
# 0     AK      3
# 1     AL      8
# 2     AR     11
# 3     AZ      4
# 4     CA      9
# 5     CO      9
# 6     CT     12
# 7     DC      5
# 8     DE      9
# 9     FL      8
# 10    GA      8
# 11    HI      3
# 12    IA      3
# 13    ID      9
# 14    IL      5
# 15    IN      9
# 16    KS     13
# 17    KY      8
# 18    LA      4
# 19    MA     11
# 20    MD     17
# 21    ME     13
# 22    MI     16
# 23    MN     15
# 24    MO      7
# 25    MS     14
# 26    MT     14
# 27    NC     11
# 28    ND      6
# 29    NE      5
# 30    NH      9
# 31    NJ     18
# 32    NM      6
# 33    NV     14
# 34    NY     15
# 35    OH     10
# 36    OK      9
# 37    OR     11
# 38    PA      8
# 39    RI      6
# 40    SC     14
# 41    SD      8
# 42    TN      5
# 43    TX     18
# 44    UT     10
# 45    VA      5
# 46    VT      8
# 47    WA     14
# 48    WI      7
# 49    WV     10
# 50    WY      9

# %%
# Total churn customers
df1=df.query("Churn == 1").groupby(["State","Area code"])["Churn"].count().reset_index()

# %%
df1
# Out:
#     State  Area code  Churn
# 0      AK        415      3
# 1      AL        408      4
# 2      AL        415      3
# 3      AL        510      1
# 4      AR        408      1
# ..    ...        ...    ...
# 134    WV        408      1
# 135    WV        415      3
# 136    WV        510      6
# 137    WY        415      5
# 138    WY        510      4
#
# [139 rows x 3 columns]

# %%
df2=df1.where(df1['Area code']==0)
df2['Churn'].sum()
# Out:
# 0.0

# %%
df['Area code'].unique()
# Out:
# array([415, 408, 510])

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
# convert area code in to lable encoder
##san jose(408)=0
#san fransisco(415)=1

#okland(510)=2

df['area_code']= label_encoder.fit_transform(df['Area code'])

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night charge  \
# 0             45.07              197.4  ...               11.01
# ...

# %%
##san jose(408)=0
#san fransisco(415)=1

#okland(510)=2

df['area_code'].value_counts()
# Out:
# 1    1655
# 2     840
# 0     838
# Name: area_code, dtype: int64

# %%
df.query("Churn == 1").groupby(["area_code"])["Churn"].count().reset_index()
# Out:
#    area_code  Churn
# 0          0    122
# 1          1    236
# 2          2    125

# %%
df.query("Churn == 0").groupby(["area_code"])["Churn"].count().reset_index()
# Out:
#    area_code  Churn
# 0          0    716
# 1          1   1419
# 2          2    715

# %%
df.head(3)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
#
#    Total day charge  Total eve minutes  ...  Total night charge  \
# 0             45.07              197.4  ...               11.01
# 1             27.47              195.5  ...               11.45
# 2             41.38              121.2  ...                7.32
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# ...

# %%
df.query("Churn == 0").groupby(["area_code"])["Churn"].count().reset_index()
# Out:
#    area_code  Churn
# 0          0    716
# 1          1   1419
# 2          2    715

# %%
df.groupby('area_code')['total_charge'].sum()
# Out:
# area_code
# 0    49382.59
# 1    98988.79
# 2    49774.65
# Name: total_charge, dtype: float64

# %%
df.groupby('area_code')['Total night charge'].sum()
# Out:
# area_code
# 0     7512.49
# 1    15046.92
# 2     7568.66
# Name: Total night charge, dtype: float64

# %%
df.groupby('area_code')['Total eve charge'].sum()
# Out:
# area_code
# 0    14337.60
# 1    28226.97
# 2    14374.87
# Name: Total eve charge, dtype: float64

# %%
df.groupby('area_code')['Total day charge'].sum()
# Out:
# area_code
# 0    25240.79
# 1    51092.06
# 2    25531.32
# Name: Total day charge, dtype: float64

# %%
df1=df.query("Chrun == 1" and "area_code==0").groupby("State")["area_code"].count().reset_index()

# %%
df1['area_code'].sum()
# Out:
# 838

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
